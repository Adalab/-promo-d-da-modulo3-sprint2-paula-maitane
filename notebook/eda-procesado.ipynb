# %% [markdown]
# # **Ejercicios de pair programming Módulo 3 Sprint 2**
# ## **Tableau**
# ---

# %%
# Tratamiento de los datos
# ========================
import pandas as pd
import numpy as np

# Importación de variables y funciones
# ====================================
import sys
sys.path.append('../')
from src import soporte_funciones as spf

# Establecer preferencias de visualización
# ========================================
pd.options.display.max_columns = None

# %%
df = pd.read_csv('../datos/shooting_1982-2023_cleaned.csv', index_col=0)
df.sample()
# Out:
#                                          location        date  \
# case
# Trestle Trail bridge shooting  Menasha, Wisconsin  2015-11-06
#
#                                                                          summary  \
# case
# Trestle Trail bridge shooting  Sergio Valencia del Toro, 27, in what official...
#
#                                fatalities  injured  total_victims location.1  \
# case
# Trestle Trail bridge shooting           3        1              4      Other
#
#                                age_of_shooter  \
# case
# Trestle Trail bridge shooting              27
#
#                               prior_signs_mental_health_issues  \
# case
# Trestle Trail bridge shooting                              Yes
#
#                                                            mental_health_details  \
# case
# Trestle Trail bridge shooting  While serving in the Air Force, he went to an ...
#
#                               weapons_obtained_legally where_obtained  \
# case
# ...

# %%
spf.explorar_df(df, 'tiroteos USA')
# Out:
# EXPLORACIÓN DEL DATAFRAME TIROTEOS USA
# ---------------------------------------------------------------------------
# Las primeras 5 filas del dataframe tiroteos USA son:
#                                                       location        date  \
# case
# Nashville religious school shooting              Nashville, TN  2023-03-27
# Michigan State University shooting      East Lansing, Michigan  2023-02-13
# Half Moon Bay spree shooting         Half Moon Bay, California  2023-01-23
# LA dance studio mass shooting        Monterey Park, California  2023-01-21
# Virginia Walmart shooting                 Chesapeake, Virginia  2022-11-22
#
#                                                                                summary  \
# case
# Nashville religious school shooting  Audrey Hale, 28, who was a former student at t...
# Michigan State University shooting   Anthony D. McRae, 43, opened fire at Berkey Ha...
# ...

# %%
df[df['age_of_shooter'] == 0]
# Out:
#                                                    location        date  \
# case
# Sacramento County church shooting    Sacramento, California  2022-02-28
# Jersey City kosher market shooting  Jersey City, New Jersey  2019-12-10
#
#                                                                               summary  \
# case
# Sacramento County church shooting   "A man believed to be meeting his three childr...
# Jersey City kosher market shooting  David N. Anderson, 47, and Francine Graham, 50...
#
#                                     fatalities  injured  total_victims  \
# case
# Sacramento County church shooting            4        0              4
# Jersey City kosher market shooting           4        3              7
#
#                                    location.1  age_of_shooter  \
# case
# Sacramento County church shooting   Religious               0
# Jersey City kosher market shooting      Other               0
#
# ...

# %%
df.loc["Jersey City kosher market shooting", "summary"]
# Out:
# 'David N. Anderson, 47, and Francine Graham, 50, were heavily armed and traveling in a white van when they first killed a police officer in a cemetery, and then opened fire at a kosher market, “fueled both by anti-Semitism and anti-law enforcement beliefs,” according to New Jersey authorities. The pair, linked to the antisemitic ideology of the Black Hebrew Israelites extremist group, were killed after a lenghty gun battle with police at the market.'

# %%
df.loc["Jersey City kosher market shooting", "age_of_shooter"] = (round((47+50)/2, 0))
df.loc["Jersey City kosher market shooting", "age_of_shooter"]
# Out:
# 48

# %%
df.loc["Jersey City kosher market shooting", "age_group"] = 'Middle Adulthood'
df.loc["Jersey City kosher market shooting", "age_group"]
# Out:
# 'Middle Adulthood'

# %%
df.loc["Sacramento County church shooting", "age_of_shooter"] = df['age_of_shooter'].median()
df.loc["Sacramento County church shooting", "age_of_shooter"]
# Out:
# 32

# %%
df.loc["Sacramento County church shooting", "age_group"] = 'Early Adulthood'
df.loc["Sacramento County church shooting", "age_group"]
# Out:
# 'Early Adulthood'

# %%
df[df['age_of_shooter'] == 0]
# Out:
# Empty DataFrame
# Columns: [location, date, summary, fatalities, injured, total_victims, location.1, age_of_shooter, prior_signs_mental_health_issues, mental_health_details, weapons_obtained_legally, where_obtained, weapon_type, weapon_details, race, gender, latitude, longitude, type, year, quarter, half, month_name, day_of_week, age_group, decade, name, current_age, description]
# Index: []

# %%
df['age_group'].unique()
# Out:
# array(['Early Adulthood', 'Middle Adulthood', 'Old Age', 'Teenage'],
#       dtype=object)

# %%
df['age_of_shooter'].unique()
# Out:
# array([28, 43, 67, 72, 31, 22, 15, 20, 21, 70, 23, 45, 18, 32, 57, 19, 44,
#        51, 48, 36, 24, 40, 46, 26, 54, 29, 38, 17, 47, 37, 64, 39, 25, 33,
#        27, 34, 42, 59, 41, 52, 16, 66, 11, 35, 55, 50])

# %%
df['current_age'].unique()
# Out:
# array([' 28', ' 43', ' 67', ' 72', ' 31', ' 22', ' 15', ' 20', ' 21',
#        ' 70', ' 23', ' 45', ' 18',
#        ' police officials said. Sheriff Scott Jones of Sacramento County told reporters at the scene that the gunman had a restraining order against him',
#        ' a 15-year-old student at Oxford High School', ' 57', ' 19',
#        ' 44', ' 51', ' 47', ' 36', ' 24', ' 40', ' 32', ' 46', ' 26',
#        ' 54', ' 29', ' 38', ' a 17-year-old student',
#        ' a 26-year-old ex-US Air Force airman', ' 37', ' 64',
#        ' a 24-year-old worker at Weis grocery fatally shot three of his fellow employees. He reportedly fired 59 rounds with a pair of shotguns before turning the gun on himself as another co-worker fled the scene for help and law enforcement responded.',
#        ' Jr.', ' 39', ' a 25-year-old Army veteran',
#        ' who worked as a painter at a manufacturing company',
#        ' a driver for Uber',
# ...

# %%
df.isnull().sum()
# Out:
# location                            0
# date                                0
# summary                             0
# fatalities                          0
# injured                             0
# total_victims                       0
# location.1                          0
# age_of_shooter                      0
# prior_signs_mental_health_issues    0
# mental_health_details               0
# weapons_obtained_legally            0
# where_obtained                      0
# weapon_type                         0
# weapon_details                      1
# race                                0
# gender                              0
# latitude                            0
# longitude                           0
# type                                0
# year                                0
# quarter                             0
# half                                0
# month_name                          0
# day_of_week                         0
# age_group                           0
# ...

# %%
df['state'] = df['location'].str.split(', ', expand=True).get(1)
df.sample()
# Out:
#                               location        date  \
# case
# Red Lake massacre  Red Lake, Minnesota  2005-03-21
#
#                                                              summary  \
# case
# Red Lake massacre  Jeffrey Weise, 16, murdered his grandfather, w...
#
#                    fatalities  injured  total_victims location.1  \
# case
# Red Lake massacre          10        5             15     School
#
#                    age_of_shooter prior_signs_mental_health_issues  \
# case
# Red Lake massacre              16                              Yes
#
#                                                mental_health_details  \
# case
# Red Lake massacre  He voluntarily visited a a psychiatric ward. H...
#
#                   weapons_obtained_legally  \
# case
# Red Lake massacre                       No
#
#                                                 where_obtained  \
# case
# Red Lake massacre  Glock and Remington stolen from grandfather
#
# ...

# %%
len(df['state'].unique())
# Out:
# 39

# %%
df['state'].unique()
# Out:
# array(['TN', 'Michigan', 'California', 'Virginia', 'Colorado',
#        'North Carolina', 'Indiana', 'Illinois', 'Alabama', 'Maryland',
#        'Oklahoma', 'Texas', 'New York', 'Georgia', 'Missouri',
#        'Wisconsin', 'New Jersey', 'Florida', 'Ohio', 'Pennsylvania',
#        'Tennessee', 'Nevada', 'Washington', 'Lousiana', 'Kansas',
#        'Oregon', 'South Carolina', 'D.C.', 'Connecticut', 'Minnesota',
#        'Arizona', 'Kentucky', 'Nebraska', 'Utah', 'Mississippi',
#        'Massachusetts', 'Hawaii', 'Arkansas', 'Iowa'], dtype=object)

# %%
df['state'] = df['state'].replace('TN', 'Tennessee')
df['state'] = df['state'].replace('D.C.', 'District of Columbia')
df['state'].unique()
# Out:
# array(['Tennessee', 'Michigan', 'California', 'Virginia', 'Colorado',
#        'North Carolina', 'Indiana', 'Illinois', 'Alabama', 'Maryland',
#        'Oklahoma', 'Texas', 'New York', 'Georgia', 'Missouri',
#        'Wisconsin', 'New Jersey', 'Florida', 'Ohio', 'Pennsylvania',
#        'Nevada', 'Washington', 'Lousiana', 'Kansas', 'Oregon',
#        'South Carolina', 'District of Columbia', 'Connecticut',
#        'Minnesota', 'Arizona', 'Kentucky', 'Nebraska', 'Utah',
#        'Mississippi', 'Massachusetts', 'Hawaii', 'Arkansas', 'Iowa'],
#       dtype=object)

# %%
df.to_csv('../datos/shooting_1982-2023_cleaned2.csv')

# %%
df.reset_index(inplace=True)

# %%
airport = df[df['case'] == 'Fort Lauderdale airport shooting']
airport
# Out:
#                                 case                  location        date  \
# 56  Fort Lauderdale airport shooting  Fort Lauderdale, Florida  2017-06-01
#
#                                               summary  fatalities  injured  \
# 56  Esteban Santiago, 26, flew from Alaska to Fort...           5        6
#
#     total_victims location.1  age_of_shooter prior_signs_mental_health_issues  \
# 56             11    Airport              26                              Yes
#
#                                 mental_health_details  \
# 56  Among other signs, Santiago had gone to a FBI ...
#
#    weapons_obtained_legally where_obtained              weapon_type  \
# 56                      Yes        Unknown  semiautomatic handgun\n
#
#                         weapon_details    race gender   latitude  longitude  \
# 56  Walther 9mm semi-automatic pistol[  Latino   Male  26.072751 -80.143382
#
#     type  year  quarter  half month_name day_of_week        age_group  decade  \
# ...

# %%
vegas = df[df['case'] == 'Las Vegas Strip massacre']
vegas
# Out:
#                         case           location        date  \
# 50  Las Vegas Strip massacre  Las Vegas, Nevada  2017-10-01
#
#                                               summary  fatalities  injured  \
# 50  Stephen Craig Paddock, 64, fired a barrage of ...          58      546
#
#     total_victims location.1  age_of_shooter prior_signs_mental_health_issues  \
# 50            604      Other              64                              TBD
#
#                                 mental_health_details  \
# 50  Perpetrator's history unclear. In 1969 Paddock...
#
#    weapons_obtained_legally           where_obtained  \
# 50                      Yes  Two gun shops in Nevada
#
#                                           weapon_type  \
# 50  23 firearms, mostly rifles; including scopes, ...
#
#                                        weapon_details   race gender  \
# 50  AR-15-style and AK-47-style rifles and "a larg...  White   Male
#
# ...
